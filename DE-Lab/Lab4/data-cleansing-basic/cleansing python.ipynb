# %%
import pandas as pd   # import the pandas library
dataset = pd.read_csv("Student_Weight_Status_Category_Reporting_Results__Beginning_2010.csv") # load data to memory
dataset
# Out:
#       LOCATION CODE       COUNTY  \
# 0             10402       ALBANY
# 1             10402       ALBANY
# 2             10402       ALBANY
# 3             10500       ALBANY
# 4             10500       ALBANY
# 5             10500       ALBANY
# 6             10601       ALBANY
# 7             10601       ALBANY
# 8             10601       ALBANY
# 9             10623       ALBANY
# 10            10623       ALBANY
# 11            10623       ALBANY
# 12            10701       ALBANY
# 13            10701       ALBANY
# 14            10701       ALBANY
# 15            10802       ALBANY
# 16            10802       ALBANY
# 17            10802       ALBANY
# 18            20101     ALLEGANY
# 19            20101     ALLEGANY
# 20            20101     ALLEGANY
# 21            21102     ALLEGANY
# 22            21102     ALLEGANY
# 23            21102     ALLEGANY
# 24            21601     ALLEGANY
# 25            21601     ALLEGANY
# 26            21601     ALLEGANY
# ...

# %%
dataset["STREET ADDRESS"].isnull() # find missing data
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3240    False
# 3241    False
# 3242    False
# 3243    False
# 3244    False
# 3245    False
# 3246    False
# 3247    False
# 3248    False
# 3249    False
# 3250    False
# 3251    False
# 3252    False
# 3253    False
# 3254    False
# 3255    False
# 3256    False
# 3257    False
# 3258    False
# 3259    False
# 3260    False
# 3261    False
# 3262    False
# 3263    False
# 3264    False
# 3265    False
# 3266    False
# 3267     True
# 3268     True
# 3269     True
# ...

# %%
dataset["STREET ADDRESS"].isnull().value_counts() # count missing data
# Out:
# False    3075
# True      195
# Name: STREET ADDRESS, dtype: int64

# %%
dataset["NO. OVERWEIGHT"].isnull().value_counts() # count missing data
# Out:
# False    3078
# True      192
# Name: NO. OVERWEIGHT, dtype: int64

# %%
 dataset["NO. OVERWEIGHT"].fillna(dataset["NO. OVERWEIGHT"].mean()) # use mean to fill in missing data
# Out:
# 0         124.000000
# 1          74.000000
# 2          50.000000
# 3          84.000000
# 4          58.000000
# 5          26.000000
# 6         231.000000
# 7         145.000000
# 8          86.000000
# 9         237.000000
# 10         94.000000
# 11        143.000000
# 12         12.000000
# 13        228.782326
# 14        228.782326
# 15        192.000000
# 16        103.000000
# 17         89.000000
# 18         35.000000
# 19         21.000000
# 20         14.000000
# 21          7.000000
# 22        228.782326
# 23        228.782326
# 24         27.000000
# 25         24.000000
# 26        228.782326
# 27         16.000000
# 28          8.000000
# 29          8.000000
#             ...
# 3240      209.000000
# 3241      122.000000
# 3242       87.000000
# 3243      161.000000
# 3244       88.000000
# 3245       72.000000
# 3246       68.000000
# 3247       30.000000
# 3248       33.000000
# 3249       57.000000
# 3250       32.000000
# 3251       25.000000
# ...
